# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
x = tips[['total_bill']]
y = tips['tip']

# %%
plt.scatter(x,y)
plt.xlabel('Total_bill')
plt.ylabel('Tip')
plt.title('total_bill vs tip'
          )

plt.show()

# %%
# now import train test split from the sklearn 
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.3,random_state=20)

# %%
x_train.shape
# Out:
# (170, 1)

# %%
y_train.shape
# Out:
# (170,)

# %%
x_test.shape
# Out:
# (74, 1)

# %%
y_test.shape
# Out:
# 87     4.00
# 236    1.00
# 209    2.23
# 153    2.00
# 128    2.00
#        ...
# 64     2.64
# 73     5.00
# 92     1.00
# 184    3.00
# 171    3.16
# Name: tip, Length: 74, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

# %%
y_test
# Out:
# 87     4.00
# 236    1.00
# 209    2.23
# 153    2.00
# 128    2.00
#        ...
# 64     2.64
# 73     5.00
# 92     1.00
# 184    3.00
# 171    3.16
# Name: tip, Length: 74, dtype: float64

# %%
model = LinearRegression()
model
# Out:
# LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_test
# Out:
# 87     4.00
# 236    1.00
# 209    2.23
# 153    2.00
# 128    2.00
#        ...
# 64     2.64
# 73     5.00
# 92     1.00
# 184    3.00
# 171    3.16
# Name: tip, Length: 74, dtype: float64

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([2.77940196, 2.1678348 , 2.18506204, 3.45449459, 2.03647706,
#        1.59179882, 4.34600447, 3.26822501, 2.0138663 , 2.7955525 ,
#        2.8332371 , 3.74843444, 3.32313685, 2.24105058, 5.4528549 ,
#        2.29811583, 3.1476343 , 6.00843353, 2.72556682, 4.54196437,
#        2.74064066, 2.0892355 , 1.59179882, 2.35195097, 3.70321293,
#        2.25289431, 2.22490004, 3.08949236, 3.72367028, 3.02166008,
#        3.07334181, 3.25207447, 2.69218904, 3.01735327, 3.73766741,
#        2.03324695, 2.25612442, 4.35354139, 3.40388956, 3.53417059,
#        2.99581922, 1.92449997, 6.01489374, 1.95787776, 5.13630429,
#        2.66957828, 3.73982082, 4.22541376, 2.58236536, 3.23269382,
#        4.0843657 , 4.9812591 , 1.88143186, 2.50053595, 2.37025492,
#        2.06985485, 3.93039721, 1.84482397, 1.99771576, 2.06124122,
#        4.29970625, 2.34656745, 2.90429948, 2.78047867, 2.16137458,
#        6.28191603, 5.58098253, 3.20469955, 2.60497612, 2.70510947,
#        3.53309389, 1.43029341, 5.177219  , 2.51345638])

# %%
# now measure the root mean square, mean absolute error, mean squared error and r2 score

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,root_mean_squared_error,r2_score

# %%
print(mean_absolute_error(y_test,y_pred))
print(mean_squared_error(y_test,y_pred))
print(root_mean_squared_error(y_test,y_pred))
# Out:
# 0.9223752739538359
# 1.6040071709677917
# 1.2664940469531594

# %%
r2 =  (r2_score(y_test,y_pred))
r2
# Out:
# 0.38941773037093486

# %%
n = x_test.shape[0]     # number of rows
p = x_test.shape[1]     # number of features

adjusted_r2 = 1 - ((1 - r2) * (n - 1) / (n - p - 1))

print("Adjusted R²:", adjusted_r2)
# Out:
# Adjusted R²: 0.3809374210705312

# %%
plt.scatter(x,y)
plt.plot(x, model.predict(x), color='red')  # regression line
plt.xlabel('Total_bill')
plt.ylabel('Tip')
plt.title('Total_bill vs Tip')
plt.show()
